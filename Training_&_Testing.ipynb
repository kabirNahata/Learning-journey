# %% [markdown]
# <a href="https://colab.research.google.com/github/kabirNahata/Learning-journey/blob/main/Training_%26_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("carprices (1).csv")

# %%
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
reg = LinearRegression()

# %%
x = df.drop("Sell Price($)", axis = 'columns')

# %%
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# The select values will change

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 15    25400         3
# 4     46000         4
# 16    28000         2
# 8     91000         8
# 18    87600         8
# 9     67000         6
# 0     69000         6
# 5     59000         5
# 6     52000         5
# 11    79000         7
# 7     72000         6
# 14    82450         7
# 1     35000         3
# 2     57000         5
# 13    58780         4
# 12    59000         5

# %% [markdown]
# The selected values will not change

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 10 )

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 18    87600         8
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([22666.14382564, 14042.98560861, 24830.00842483, 25340.3861489 ])

# %%
reg.score(x_test,y_test)
# Out:
# 0.9101198632881725
